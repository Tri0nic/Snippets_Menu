# %%
{
    "name" : "Мои шаблоны",
    "sub-menu" : 
    [
        {
            "name" : "Библиотеки",
            "sub-menu" : 
            [
                {
                    "name" : "Стандартные",
                    "snippet" :
                    ["import numpy as np",
                    "import pandas as pd",
                    "import matplotlib.pyplot as plt"]
                },
                {
                    "name" : "ML",
                    "sub-menu" :
                    [
                        {
                            "name" : "Классификация",
                            "snippet" :
                            ["from sklearn.model_selection import train_test_split",
                            "",
                            "from sklearn.neighbors import KNeighborsClassifier",
                            "from sklearn.linear_model import LogisticRegression",
                            "from sklearn.svm import LinearSVC",
                            "from sklearn.ensemble import RandomForestClassifier",
                            "from sklearn.ensemble import GradientBoostingClassifier",
                            "from sklearn.svm import SVC",
                            "from sklearn.neural_network import MLPClassifier"]
                        },
                        {
                            "name" : "Регрессия",
                            "snippet" :
                            ["from sklearn.model_selection import train_test_split",
                            "",
                            "from sklearn.neighbors import KNeighborsRegressor",
                            "from sklearn.linear_model import LinearRegression",
                            "from sklearn.linear_model import Ridge",
                            "from sklearn.linear_model import Lasso",
                            "from sklearn.ensemble import RandomForestRegressor",
                            "from sklearn.ensemble import GradientBoostingRegressor",
                            "from sklearn.svm import SVR",
                            "from sklearn.neural_network import MLPRegressor"]
                        },
                        {
                            "name" : "Масштабирование",
                            "snippet" :
                            ["from sklearn.preprocessing import MinMaxScaler",
                            "from sklearn.preprocessing import StandardScaler"]
                        }
                    ]
                }
            ]
        },
        {
            "name" : "Pandas",
            "sub-menu" : 
            [
                {
                    "name" : "Стандарт",
                    "sub-menu" : 
                    [
                        {
                            "name" : "Импорт",
                            "sub-menu" : 
                            [
                                {
                                    "name" : "excel",
                                    "snippet" :
                                    ["df = pd.read_excel('file_name.xlsx', sheet_name='sheet_name', header = 0)"]
                                },
                                {
                                    "name" : "csv",
                                    "snippet" :
                                    ["df = pd.read_csv('file_name.csv', header=0)"]
                                }
                            ]
                        },
                        {
                            "name" : "Экспорт",
                            "sub-menu" : 
                            [
                                {
                                    "name" : "excel",
                                    "snippet" :
                                    ["# ids = test['PassengerId']",
                                    "# predictions = GradBoostC.predict(test.drop('PassengerId', axis=1))",
                                    "",
                                    "output = pd.DataFrame({ 'column_name_1' : column_1, 'column_name_2': column_2 })",
                                    "output.to_excel('submission.xlsx', index=False)"]
                                },
                                {
                                    "name" : "csv",
                                    "snippet" :
                                    ["# ids = test['PassengerId']",
                                    "# predictions = GradBoostC.predict(test.drop('PassengerId', axis=1))",
                                    "",
                                    "output = pd.DataFrame({ 'column_name_1' : column_1, 'column_name_2': column_2 })",
                                    "output.to_csv('submission.scv', index=False)"]
                                }
                            ]
                        },
                        {
                            "name" : "shape",
                            "snippet" :
                            ["df.shape"]
                        },
                        {
                            "name" : "head()",
                            "snippet" :
                            ["df.head()"]
                        },
                        {
                            "name" : "describe()",
                            "snippet" :
                            ["df.describe()"]
                        }
                    ]
                },
                {
                    "name" : "Вывод строк",
                    "sub-menu" : 
                    [
                        {
                            "name" : "По номеру индекса",
                            "snippet" :
                            ["df.iloc[[i for i in range(a, b)]]"]
                        }
                    ]
                },
                {
                    "name" : "Вывод столбцов",
                    "sub-menu" : 
                    [
                        {
                            "name" : "По названию",
                            "snippet" :
                            ["df.loc[ :, ['column_name']]"]
                        },
                        {
                            "name" : "С пропущенными значениями в столбце",
                            "snippet" :
                            ["df[df['column_name'].isnull() == True]"]
                        },
                        {
                            "name" : "С определенными значениями в другом столбце",
                            "snippet" :
                            ["df[df['column_name'] == value][['shown_column']]"]
                        }
                    ]
                },
                {
                    "name" : "Подсчет",
                    "sub-menu" : 
                    [
                        {
                            "name" : "Значений в каждом столбце",
                            "snippet" :
                            ["# Подсчет значений в каждом столбце",
                            "table = pd.DataFrame()",
                            "df = df",
                            "for i in range(len(list(df.columns))):",
                            "    table[list(df.columns)[i]] = pd.DataFrame(list(df[list(df.columns)[i]].value_counts().index))",
                            "    table['Кол_' + list(df.columns)[i]] = pd.DataFrame(list(df[list(df.columns)[i]].value_counts()))",
                            "table[:5]"]
                        }
                    ]
                },
                {
                    "name" : "Удаление строк/столбцов",
                    "sub-menu" : 
                    [
                        {
                            "name" : "По названиям",
                            "snippet" :
                            ["df = df.drop(['column_name'], axis = 1)"]
                        },
                        {
                            "name" : "В зависимости от количества пропусков",
                            "snippet" :
                            ["df = df.dropna(thresh=n)"]
                        }
                    ]
                },
                {
                    "name" : "Обработка пропущенных значений",
                    "sub-menu" : 
                    [
                        {
                            "name" : "Суммы пропущенных значений в столбцах",
                            "snippet" :
                            ["pd.isnull(df).sum()"]
                        },
                        {
                            "name" : "Подсчет нулевых значений в столбце",
                            "snippet" :
                            ["df['column_name'].isnull().value_counts()"]
                        },
                        {
                            "name" : "Вывод пустых строк",
                            "snippet" :
                            ["df[df['column_name'].isnull() == True]"]
                        },
                        {
                            "name" : "Заполнение пустых значений средним",
                            "snippet" :
                            ["df.loc[df['column_name'].isnull() == True, 'column_name'] = df['column_name'].mean()"]
                        }
                    ]
                },
                {
                    "name" : "Замена значений",
                    "sub-menu" : 
                    [
                        {
                            "name" : "Прямое указание",
                            "snippet" :
                            ["df = df.replace({'column_name_1':{'old_1':'new', 'old_2':0}, 'column_name_2':{2:1})"]
                        }
                    ]
                },
                {
                    "name" : "Графики",
                    "sub-menu" : 
                    [
                        {
                            "name" : "Точечная матрица",
                            "snippet" :
                            ["pd.plotting.scatter_matrix(df[['first_column', 'second_column']], figsize=(10, 10));"]
                        }
                    ]
                }
            ]
        },
        {
            "name" : "NumPy",
            "sub-menu" : 
            [
                {
                    "name" : "1",
                    "snippet" :
                    ["import numpy as np",
                    "import pandas as pd",
                    "import matplotlib.pyplot as plt"]
                },
                {
                    "name" : "2",
                    "snippet" :
                    ["import numpy as np",
                    "import pandas as pd",
                    "import matplotlib.pyplot as plt"]
                },
                {
                    "name" : "3",
                    "snippet" :
                    ["import numpy as np",
                    "import pandas as pd",
                    "import matplotlib.pyplot as plt"]
                },
                {
                    "name" : "4",
                    "snippet" :
                    ["import numpy as np",
                    "import pandas as pd",
                    "import matplotlib.pyplot as plt"]
                },
                {
                    "name" : "5",
                    "snippet" :
                    ["import numpy as np",
                    "import pandas as pd",
                    "import matplotlib.pyplot as plt"]
                }
            ]
        },
        {
            "name" : "Matplotlib",
            "sub-menu" : 
            [
                {
                    "name" : "1",
                    "snippet" :
                    ["import numpy as np",
                    "import pandas as pd",
                    "import matplotlib.pyplot as plt"]
                },
                {
                    "name" : "2",
                    "snippet" :
                    ["import numpy as np",
                    "import pandas as pd",
                    "import matplotlib.pyplot as plt"]
                },
                {
                    "name" : "3",
                    "snippet" :
                    ["import numpy as np",
                    "import pandas as pd",
                    "import matplotlib.pyplot as plt"]
                },
                {
                    "name" : "4",
                    "snippet" :
                    ["import numpy as np",
                    "import pandas as pd",
                    "import matplotlib.pyplot as plt"]
                },
                {
                    "name" : "5",
                    "snippet" :
                    ["import numpy as np",
                    "import pandas as pd",
                    "import matplotlib.pyplot as plt"]
                }
            ]
        },
        {
            "name" : "ML",
            "sub-menu" : 
            [
                {
                    "name" : "Классификация",
                    "sub-menu" : 
                    [
                        {
                            "name" : "KNeighborsClassifier",
                            "snippet" :
                            ["KNNC = KNeighborsClassifier()",
                            "KNNC.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(KNNC.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(KNNC.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "LogisticRegression",
                            "snippet" :
                            ["LogReg = LogisticRegression()",
                            "LogReg.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(LogReg.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(LogReg.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "LinearSVC",
                            "snippet" :
                            ["LSVC = LinearSVC()",
                            "LSVC.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(LSVC.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(LSVC.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "RandomForestClassifier",
                            "snippet" :
                            ["RandForestC = RandomForestClassifier()",
                            "RandForestC.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(RandForestC.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(RandForestC.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "GradientBoostingClassifier",
                            "snippet" :
                            ["GradBoostC = GradientBoostingClassifier()",
                            "GradBoostC.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(GradBoostC.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(GradBoostC.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "SVC",
                            "snippet" :
                            ["svc = SVC()",
                            "svc.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(svc.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(svc.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "MLPClassifier",
                            "snippet" :
                            ["MLPC = MLPClassifier()",
                            "MLPC.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(MLPC.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(MLPC.score(X_test, y_test)))"]
                        }
                    ]
                },
                {
                    "name" : "Регрессия",
                    "sub-menu" : 
                    [
                        {
                            "name" : "KNeighborsRegressor",
                            "snippet" :
                            ["KNNR = KNeighborsRegressor()",
                            "KNNR.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(KNNR.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(KNNR.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "LinearRegression",
                            "snippet" :
                            ["LineReg = LinearRegression()",
                            "LineReg.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(LineReg.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(LineReg.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "Ridge",
                            "snippet" :
                            ["ridge = Ridge()",
                            "ridge.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(ridge.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(ridge.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "Lasso",
                            "snippet" :
                            ["lasso = Lasso()",
                            "lasso.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(lasso.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(lasso.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "RandomForestRegressor",
                            "snippet" :
                            ["RandForestR = RandomForestRegressor()",
                            "RandForestR.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(RandForestR.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(RandForestR.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "GradientBoostingRegressor",
                            "snippet" :
                            ["GradBoostR = GradientBoostingRegressor()",
                            "GradBoostR.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(GradBoostR.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(GradBoostR.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "SVR",
                            "snippet" :
                            ["svr = SVR()",
                            "svr.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(svr.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(svr.score(X_test, y_test)))"]
                        },
                        {
                            "name" : "MLPRegressor",
                            "snippet" :
                            ["MLPR = MLPRegressor()",
                            "MLPR.fit(X_train, y_train)",
                            "",
                            "print('Правильность на обучающем наборе: {:.4f}'.format(MLPR.score(X_train, y_train)))",
                            "print('Правильность на тестовом наборе: {:.4f}'.format(MLPR.score(X_test, y_test)))"]
                        }
                    ]
                },
                {
                    "name" : "Присваивание переменных, разбиение",
                    "sub-menu" : 
                    [
                        {
                            "name" : "train_test_split()",
                            "snippet" :
                            ["# Выделяем массив объектов",
                            "X = np.array(df[['X_column_name_1', 'X_column_name_2']])",
                            "",
                            "# Выделяем массив ответов",
                            "y = np.array(df['y_column_name'])",
                            "",
                            "# Делим данные на тренировочную и тестовую выборки",
                            "X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)"]
                        }
                    ]
                },
                {
                    "name" : "Масштабирование/нормировка",
                    "sub-menu" : 
                    [
                        {
                            "name" : "StandardScaler()",
                            "snippet" :
                            ["SS = StandardScaler()",
                            "SS.fit(X_train)",
                            "X_train_SS = SS.transform(X_train)",
                            "X_test_SS = SS.transform(X_test)"]
                        },
                        {
                            "name" : "RobustScaler()",
                            "snippet" :
                            ["RS = RobustScaler()",
                            "RS.fit(X_train)",
                            "X_train_SS = RS.transform(X_train)",
                            "X_test_SS = RS.transform(X_test)"]
                        },
                        {
                            "name" : "MinMaxScaler()",
                            "snippet" :
                            ["MMS = MinMaxScaler()",
                            "MMS.fit(X_train)",
                            "X_train_SS = MMS.transform(X_train)",
                            "X_test_SS = MMS.transform(X_test)"]
                        }
                    ]
                },
                {
                    "name" : "Одномерные нелинейные преобразования",
                    "sub-menu" : 
                    [
                        {
                            "name" : "log()",
                            "snippet" :
                            ["X_train_log = np.log(X_train + 1)",
                            "X_test_log = np.log(X_test + 1)",
                            "",
                            "y_train_log = np.log(y_train + 1)",
                            "y_test_log = np.log(y_test + 1)"]
                        },
                        {
                            "name" : "exp()",
                            "snippet" :
                            ["X_train_exp = np.exp(X_train)",
                            "X_test_exp = np.exp(X_test)",
                            "",
                            "y_train_exp = np.exp(y_train)",
                            "y_test_exp = np.exp(y_test)"]
                        },
                        {
                            "name" : "sin()",
                            "snippet" :
                            ["X_train_sin = np.sin(X_train)",
                            "X_test_sin = np.sin(X_test)",
                            "",
                            "y_train_sin = np.sin(y_train)",
                            "y_test_sin = np.sin(y_test)"]
                        },
                        {
                            "name" : "cos()",
                            "snippet" :
                            ["X_train_cos = np.cos(X_train)",
                            "X_test_cos = np.cos(X_test)",
                            "",
                            "y_train_cos = np.cos(y_train)",
                            "y_test_cos = np.cos(y_test)"]
                        }
                    ]
                },
                {
                    "name" : "Вывод",
                    "sub-menu" : 
                    [
                        {
                            "name" : "Сравнение точностей (классификация)",
                            "snippet" :
                            ["acc_KNNC = KNNC.score(X_test, y_test)",
                            "acc_LogReg = LogReg.score(X_test, y_test)",
                            "acc_LSVC = LSVC.score(X_test, y_test)",
                            "acc_RandForestC = RandForestC.score(X_test, y_test)",
                            "acc_GradBoostC = GradBoostC.score(X_test, y_test)",
                            "acc_svc = svc.score(X_test, y_test)",
                            "acc_MLPC = MLPC.score(X_test, y_test)",
                            "",
                            "models = pd.DataFrame({",
                            "    'Model': ['KNN', 'Logistic Regression', 'Linear SVC', 'Random Forest',",
                            "              'Gradient Boosting Classifier', 'SVC', 'Multi-layer Perceptron'],",
                            "    'Score': [acc_KNNC, acc_LogReg, acc_LSVC, acc_RandForestC,",
                            "              acc_GradBoostC, acc_svc, acc_MLPC]})",
                            "models.sort_values(by='Score', ascending=False)"]
                        },
                        {
                            "name" : "Сравнение точностей (регрессия)",
                            "snippet" :
                            ["acc_KNNR = KNNR.score(X_test, y_test)",
                            "acc_LineReg = LineReg.score(X_test, y_test)",
                            "acc_ridge = ridge.score(X_test, y_test)",
                            "acc_lasso = lasso.score(X_test, y_test)",
                            "acc_RandForestR = RandForestR.score(X_test, y_test)",
                            "acc_GradBoostR = GradBoostR.score(X_test, y_test)",
                            "acc_svr = svr.score(X_test, y_test)",
                            "acc_MLPR = MLPR.score(X_test, y_test)",
                            "",
                            "models = pd.DataFrame({",
                            "    'Model': ['KNN', 'Liner Regression', 'Ridge', 'Lasso','Random Forest',",
                            "              'Gradient Boosting Classifier', 'SVR', 'Multi-layer Perceptron'],",
                            "    'Score': [acc_KNNR, acc_LineReg, acc_ridge, acc_lasso,",
                            "              acc_RandForestR, acc_GradBoostR, acc_svr, acc_MLPR]})",
                            "models.sort_values(by='Score', ascending=False)"]
                        }
                    ]
                }
            ]
        }          
    ]
}
